# %% [markdown]
# # Collecting Data from the Web - APIs
#
#
# An API is a connection between computers or between computer programs. It is a type of software interface, offering a service to other pieces of software. The kinds of APIs we will use here can be used to interact with, and get data from, different web platforms using Python. Some APIs are more public than others.
#
# We're going to first explore the Google Books API to perform some searches for books and see what metadata we get in return. Although many APIs require a key in order to access the data, we can perform Google Books searches without one.
#
# Using APIs to request data is usually done through HTTP (see [here](https://developer.mozilla.org/en-US/docs/Web/HTTP/Overview) for an overview of basic terms). The guide to the Google Books API can be found [here](https://developers.google.com/books/).
#
# If you are interested in Reddit and Twitter data check out notebook 3-2_praw-tweepy.ipynb. You can also download Tweets from the Internet by Google searching "download tweets".
#
# First we'll import the [`requests`](http://docs.python-requests.org/en/master/) library. The `requests` library is necessary for most interaction with the internet in Python. We'll use it to make a `get` request to the API endpoint.

# %%
# !pip install requests

# %%
import requests
import pandas as pd
import time

# %% [markdown]
# To call an API it to just build a unique URL. We always need a base URL, or endpoint, to which we can add the parameters specific to our request. Let's assign the base Google Books endpoint to a variable, we'll call it `books_url`. We know this URL from the documentation linked above.

# %%
books_url = 'https://www.googleapis.com/books/v1/volumes?'

# %% [markdown]
# We can start off with a very simple search to see what the results look like. Then we'll move on to adding more filters and parameters. Let's assign our query to a variable `query`.

# %%
query = 'digital humanities'

# %% [markdown]
# To incorporate this into our query we can make a dictionary called `parameters`. Read more about what kinds of parameters the Google API allows for [here](https://developers.google.com/books/docs/v1/using#st_params).
#
# We'll pass these parameters to the `get` method. Read more about HTTP GET requests [here](https://www.w3schools.com/tags/ref_httpmethods.asp).
#
# The `'q'` stands for 'query', and whatever value we assign to that is what we're searching for, just as if we typed it into the Google search bar.

# %%
parameters = {'q': query}

# %% [markdown]
# We'll pass two arguments to the `get` method of `requests` library: the URL and the parameters we want. It returns a response object.

# %%
r = requests.get(books_url, params = parameters)

# %% [markdown]
# Printing the `url` property, we can see that this function converted the URL into the proper format to include our search terms.

# %%
print(r.url)
# Out:
# https://www.googleapis.com/books/v1/volumes?q=digital+humanities

# %% [markdown]
# To see our results, we simply use the request object's `json` method, which we can then navigate in the same way as a Python dictionary. Take a minute or two to navigate through the results in order to see what's there.

# %%
results = r.json()
results
# Out:
# {'kind': 'books#volumes',
#  'totalItems': 578,
#  'items': [{'kind': 'books#volume',
#    'id': 'PGV2DwAAQBAJ',
#    'etag': 'c46lXoe4Zkg',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/PGV2DwAAQBAJ',
#    'volumeInfo': {'title': 'Research Methods for the Digital Humanities',
#     'authors': ['lewis levenberg', 'Tai Neilson', 'David Rheams'],
#     'publisher': 'Springer',
#     'publishedDate': '2018-11-04',
#     'description': 'This volume introduces the reader to the wide range of methods that digital humanities employ, and offers a practical guide to the study, interpretation, and presentation of cultural material and practices. In this instance, the editors consider digital humanities to include both the use of computing to understand cultural material in new ways, and the application of theories and methods from the humanities to interpret new technologies. Each chapter provides a step-by-step guide to cutting-edge methodologies so that students can make informed decisions about the methods they use, consider ethical practices, follow practical procedures, and present their work effectively. Readers will develop practical and reflexive understandings of the software and digital devices that they study and use for research, and the book will help new researchers collaborate and contribute to their scholarly communities, and to public discourse. As contemporary humanities work becomes increasingly interdisciplinary, and increasingly permeated by and with digital technologies, this volume helps new researchers navigate an evolving academic environment. Humanities and social sciences students will find this textbook an invaluable resource for assessing and creating digital projects.',
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9783319967134'},
#      {'type': 'ISBN_10', 'identifier': '3319967134'}],
#     'readingModes': {'text': True, 'image': True},
#     'pageCount': 325,
#     'printType': 'BOOK',
#     'categories': ['Social Science'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '1.2.2.0.preview.3',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=PGV2DwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=PGV2DwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com.ar/books?id=PGV2DwAAQBAJ&printsec=frontcover&dq=digital+humanities&hl=&cd=1&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=PGV2DwAAQBAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=PGV2DwAAQBAJ'},
#    'saleInfo': {'country': 'AR',
#     'saleability': 'FOR_SALE',
#     'isEbook': True,
#     'listPrice': {'amount': 4295.69, 'currencyCode': 'ARS'},
#     'retailPrice': {'amount': 3006.98, 'currencyCode': 'ARS'},
#     'buyLink': 'https://play.google.com/store/books/details?id=PGV2DwAAQBAJ&rdid=book-PGV2DwAAQBAJ&rdot=1&source=gbs_api',
#     'offers': [{'finskyOfferType': 1,
#       'listPrice': {'amountInMicros': 4295690000, 'currencyCode': 'ARS'},
#       'retailPrice': {'amountInMicros': 3006980000, 'currencyCode': 'ARS'}}]},
#    'accessInfo': {'country': 'AR',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com.ar/books/download/Research_Methods_for_the_Digital_Humanit-sample-epub.acsm?id=PGV2DwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'pdf': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com.ar/books/download/Research_Methods_for_the_Digital_Humanit-sample-pdf.acsm?id=PGV2DwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=PGV2DwAAQBAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'This volume introduces the reader to the wide range of methods that digital humanities employ, and offers a practical guide to the study, interpretation, and presentation of cultural material and practices.'}},
#   {'kind': 'books#volume',
#    'id': 'L1TKCQAAQBAJ',
#    'etag': 'nyC3IDmGRR8',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/L1TKCQAAQBAJ',
#    'volumeInfo': {'title': 'A New Companion to Digital Humanities',
#     'authors': ['Susan Schreibman', 'Ray Siemens', 'John Unsworth'],
#     'publisher': 'John Wiley & Sons',
#     'publishedDate': '2016-01-26',
#     'description': 'This highly-anticipated volume has been extensively revised to reflect changes in technology, digital humanities methods and practices, and institutional culture surrounding the valuation and publication of digital scholarship. A fully revised edition of a celebrated reference work, offering the most comprehensive and up-to-date collection of research currently available in this rapidly evolving discipline Includes new articles addressing topical and provocative issues and ideas such as retro computing, desktop fabrication, gender dynamics, and globalization Brings together a global team of authors who are pioneers of innovative research in the digital humanities Accessibly structured into five sections exploring infrastructures, creation, analysis, dissemination, and the future of digital humanities Surveys the past, present, and future of the field, offering essential research for anyone interested in better understanding the theory, methods, and application of the digital humanities',
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781118680643'},
#      {'type': 'ISBN_10', 'identifier': '1118680642'}],
#     'readingModes': {'text': False, 'image': True},
#     'pageCount': 592,
#     'printType': 'BOOK',
#     'categories': ['Literary Criticism'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '1.4.3.0.preview.1',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=L1TKCQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=L1TKCQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com.ar/books?id=L1TKCQAAQBAJ&printsec=frontcover&dq=digital+humanities&hl=&cd=2&source=gbs_api',
#     'infoLink': 'http://books.google.com.ar/books?id=L1TKCQAAQBAJ&dq=digital+humanities&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/A_New_Companion_to_Digital_Humanities.html?hl=&id=L1TKCQAAQBAJ'},
#    'saleInfo': {'country': 'AR',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'AR',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=L1TKCQAAQBAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'This highly-anticipated volume has been extensively revised to reflect changes in technology, digital humanities methods and practices, and institutional culture surrounding the valuation and publication of digital scholarship.'}},
#   {'kind': 'books#volume',
#    'id': 'uV_XCQAAQBAJ',
#    'etag': 'Ue/P9ZlZtpY',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/uV_XCQAAQBAJ',
#    'volumeInfo': {'title': 'Defining Digital Humanities',
#     'subtitle': 'A Reader',
#     'authors': ['Dr Edward Vanhoutte'],
#     'publisher': 'Ashgate Publishing, Ltd.',
#     'publishedDate': '2013-12-23',
#     'description': 'This reader brings together the essential readings that have emerged in Digital Humanities. It provides a historical overview of how the term ‘Humanities Computing’ developed into the term ‘Digital Humanities’, and highlights core readings which explore the meaning, scope, and implementation of the field. To contextualize and frame each included reading, the editors and authors provide a commentary on the original piece. There is also an annotated bibliography of other material not included in the text to provide an essential list of reading in the discipline.',
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781409469636'},
#      {'type': 'ISBN_10', 'identifier': '1409469638'}],
#     'readingModes': {'text': False, 'image': False},
#     'pageCount': 330,
#     'printType': 'BOOK',
#     'categories': ['Language Arts & Disciplines'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=uV_XCQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=uV_XCQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com.ar/books?id=uV_XCQAAQBAJ&printsec=frontcover&dq=digital+humanities&hl=&cd=3&source=gbs_api',
#     'infoLink': 'http://books.google.com.ar/books?id=uV_XCQAAQBAJ&dq=digital+humanities&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Defining_Digital_Humanities.html?hl=&id=uV_XCQAAQBAJ'},
#    'saleInfo': {'country': 'AR',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'AR',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=uV_XCQAAQBAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'There is also an annotated bibliography of other material not included in the text to provide an essential list of reading in the discipline.'}},
#   {'kind': 'books#volume',
#    'id': 'hPhnDQAAQBAJ',
#    'etag': 'tcJBdciBPqA',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/hPhnDQAAQBAJ',
#    'volumeInfo': {'title': 'Digital Humanities in Practice',
#     'subtitle': '',
#     'authors': ['Claire Warwick', 'Melissa Terras', 'Julianne Nyhan'],
#     'publisher': 'Facet Publishing',
#     'publishedDate': '2012-10-09',
#     'description': 'This cutting-edge and comprehensive introduction to digital humanities explains the scope of the discipline and state of the art and provides a wide-ranging insight into emerging topics and avenues of research. Each chapter interweaves the expert commentary of leading academics with analysis of current research and practice, exploring the possibilities and challenges that occur when culture and digital technologies intersect. International case studies of projects ranging from crowdsourced manuscript transcription to computational reconstruction of frescoes are included in each chapter, providing a wealth of information and inspiration. QR codes within each chapter link to a dedicated website where additional content, such as further case studies, is located. Key topics covered include: • studying users and readers • social media and crowdsourcing • digitization and digital resources • image processing in the digital humanities • 3D recording and museums • electronic text and text encoding • book history, texts and digital editing • open access and online teaching of digital humanities • institutional models for digital humanities. Readership: This is an essential practical guide for academics, researchers, librarians and professionals involved in the digital humanities. It will also be core reading for all humanities students and those taking courses in the digital humanities in particular.',
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781856047661'},
#      {'type': 'ISBN_10', 'identifier': '1856047660'}],
#     'readingModes': {'text': False, 'image': True},
#     'pageCount': 192,
#     'printType': 'BOOK',
#     'categories': ['Language Arts & Disciplines'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=hPhnDQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=hPhnDQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com.ar/books?id=hPhnDQAAQBAJ&printsec=frontcover&dq=digital+humanities&hl=&cd=4&source=gbs_api',
#     'infoLink': 'http://books.google.com.ar/books?id=hPhnDQAAQBAJ&dq=digital+humanities&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Digital_Humanities_in_Practice.html?hl=&id=hPhnDQAAQBAJ'},
#    'saleInfo': {'country': 'AR',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'AR',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=hPhnDQAAQBAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Readership: This is an essential practical guide for academics, researchers, librarians and professionals involved in the digital humanities.'}},
#   {'kind': 'books#volume',
#    'id': 'zkwnDwAAQBAJ',
#    'etag': 'pm3hohjTz1E',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/zkwnDwAAQBAJ',
#    'volumeInfo': {'title': 'Digital Humanities',
#     'subtitle': 'Knowledge and Critique in a Digital Age',
#     'authors': ['David M. Berry', 'Anders Fagerjord'],
#     'publisher': 'John Wiley & Sons',
#     'publishedDate': '2017-05-30',
#     'description': 'As the twenty-first century unfolds, computers challenge the way in which we think about culture, society and what it is to be human: areas traditionally explored by the humanities. In a world of automation, Big Data, algorithms, Google searches, digital archives, real-time streams and social networks, our use of culture has been changing dramatically. The digital humanities give us powerful theories, methods and tools for exploring new ways of being in a digital age. Berry and Fagerjord provide a compelling guide, exploring the history, intellectual work, key arguments and ideas of this emerging discipline. They also offer an important critique, suggesting ways in which the humanities can be enriched through computing, but also how cultural critique can transform the digital humanities. Digital Humanities will be an essential book for students and researchers in this new field but also related areas, such as media and communications, digital media, sociology, informatics, and the humanities more broadly.',
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780745697697'},
#      {'type': 'ISBN_10', 'identifier': '0745697690'}],
#     'readingModes': {'text': True, 'image': True},
#     'pageCount': 248,
#     'printType': 'BOOK',
#     'categories': ['Social Science'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=zkwnDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=zkwnDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com.ar/books?id=zkwnDwAAQBAJ&printsec=frontcover&dq=digital+humanities&hl=&cd=5&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=zkwnDwAAQBAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=zkwnDwAAQBAJ'},
#    'saleInfo': {'country': 'AR',
#     'saleability': 'FOR_SALE',
#     'isEbook': True,
#     'listPrice': {'amount': 2772.56, 'currencyCode': 'ARS'},
#     'retailPrice': {'amount': 2772.56, 'currencyCode': 'ARS'},
#     'buyLink': 'https://play.google.com/store/books/details?id=zkwnDwAAQBAJ&rdid=book-zkwnDwAAQBAJ&rdot=1&source=gbs_api',
#     'offers': [{'finskyOfferType': 1,
#       'listPrice': {'amountInMicros': 2772560000, 'currencyCode': 'ARS'},
#       'retailPrice': {'amountInMicros': 2772560000, 'currencyCode': 'ARS'}}]},
#    'accessInfo': {'country': 'AR',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com.ar/books/download/Digital_Humanities-sample-epub.acsm?id=zkwnDwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'pdf': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com.ar/books/download/Digital_Humanities-sample-pdf.acsm?id=zkwnDwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=zkwnDwAAQBAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Berry and Fagerjord provide a compelling guide, exploring the history, intellectual work, key arguments and ideas of this emerging discipline.'}},
#   {'kind': 'books#volume',
#    'id': 'iSIzDwAAQBAJ',
#    'etag': 'TqWRb9yphqM',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/iSIzDwAAQBAJ',
#    'volumeInfo': {'title': 'The Digital Humanities and the Digital Modern',
#     'authors': ['James Smithies'],
#     'publisher': 'Springer',
#     'publishedDate': '2017-08-28',
#     'description': 'This book provides new critical and methodological approaches to digital humanities, intended to guide technical development as well as critical analysis. Informed by the history of technology and culture and new perspectives on modernity, Smithies grounds his claims in the engineered nature of computing devices and their complex entanglement with our communities, our scholarly traditions, and our sense of self. The distorting mentalité of the digital modern informs our attitudes to computers and computationally intensive research, leading scholars to reject articulations of meaning that admit the interdependence of humans and the complex socio-technological systems we are embedded in. By framing digital humanities with the digital modern, researchers can rebuild our relationship to technical development, and seek perspectives that unite practical and critical activity. This requires close attention to the cyber-infrastructures that inform our research, the software-intensive methods that are producing new knowledge, and the ethical issues implicit in the production of digital humanities tools and methods. The book will be of interest to anyone interested in the intersection of technology with humanities research, and the future of digital humanities.',
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781137499448'},
#      {'type': 'ISBN_10', 'identifier': '1137499443'}],
#     'readingModes': {'text': True, 'image': True},
#     'pageCount': 268,
#     'printType': 'BOOK',
#     'categories': ['Social Science'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '0.0.1.0.preview.3',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=iSIzDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=iSIzDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com.ar/books?id=iSIzDwAAQBAJ&printsec=frontcover&dq=digital+humanities&hl=&cd=6&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=iSIzDwAAQBAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=iSIzDwAAQBAJ'},
#    'saleInfo': {'country': 'AR',
#     'saleability': 'FOR_SALE',
#     'isEbook': True,
#     'listPrice': {'amount': 14731.07, 'currencyCode': 'ARS'},
#     'retailPrice': {'amount': 10311.75, 'currencyCode': 'ARS'},
#     'buyLink': 'https://play.google.com/store/books/details?id=iSIzDwAAQBAJ&rdid=book-iSIzDwAAQBAJ&rdot=1&source=gbs_api',
#     'offers': [{'finskyOfferType': 1,
#       'listPrice': {'amountInMicros': 14731070000, 'currencyCode': 'ARS'},
#       'retailPrice': {'amountInMicros': 10311750000, 'currencyCode': 'ARS'}}]},
#    'accessInfo': {'country': 'AR',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com.ar/books/download/The_Digital_Humanities_and_the_Digital_M-sample-epub.acsm?id=iSIzDwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'pdf': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com.ar/books/download/The_Digital_Humanities_and_the_Digital_M-sample-pdf.acsm?id=iSIzDwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=iSIzDwAAQBAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'This book provides new critical and methodological approaches to digital humanities, intended to guide technical development as well as critical analysis.'}},
#   {'kind': 'books#volume',
#    'id': 'aC1WDwAAQBAJ',
#    'etag': '64WRTpy53yY',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/aC1WDwAAQBAJ',
#    'volumeInfo': {'title': 'Research Methods for Reading Digital Data in the Digital Humanities',
#     'authors': ['Gabriele Griffin'],
#     'publisher': 'Edinburgh University Press',
#     'publishedDate': '2016-02-15',
#     'description': 'The first volume to introduce the techniques and methods of reading digital material for researchDigital Humanities has become one of the new domains of academe at the interface of technological development, epistemological change, and methodological concerns. This volume explores how digital material might be read or utilized in research, whether that material is digitally born as fanfiction, for example, mostly is, or transposed from other sources. The volume asks questions such as what happens when text is transformed from printed into digital matter, and how that impacts on the methods we bring to bear on exploring that technologized matter, for example in the case of digital editions. Issues such as how to analyse visual material in digital archives or Twitter feeds, how to engage in data mining, what it means to undertake crowd-sourcing, big data, and what digital network analyses can tell us about online interactions are dealt with. This will give Humanities researchers ideas for doing digitally based research and also suggest ways of engaging with new digital research methods. Key featuresFirst volume centred on the navigation and interpretation of digital material as research methods in the HumanitiesUp-to-date analyses of issues and methods including big data, crowdsourcing, digital network analysis, working with digital additionsBased on actual research projects such as para-textual work with fanfiction, reading twitter, different kinds of distant and close readings',
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781474409629'},
#      {'type': 'ISBN_10', 'identifier': '1474409628'}],
#     'readingModes': {'text': False, 'image': True},
#     'pageCount': 256,
#     'printType': 'BOOK',
#     'categories': ['Reference'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '0.1.1.0.preview.1',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=aC1WDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=aC1WDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com.ar/books?id=aC1WDwAAQBAJ&printsec=frontcover&dq=digital+humanities&hl=&cd=7&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=aC1WDwAAQBAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=aC1WDwAAQBAJ'},
#    'saleInfo': {'country': 'AR',
#     'saleability': 'FOR_SALE',
#     'isEbook': True,
#     'listPrice': {'amount': 11658.2, 'currencyCode': 'ARS'},
#     'retailPrice': {'amount': 8160.74, 'currencyCode': 'ARS'},
#     'buyLink': 'https://play.google.com/store/books/details?id=aC1WDwAAQBAJ&rdid=book-aC1WDwAAQBAJ&rdot=1&source=gbs_api',
#     'offers': [{'finskyOfferType': 1,
#       'listPrice': {'amountInMicros': 11658200000, 'currencyCode': 'ARS'},
#       'retailPrice': {'amountInMicros': 8160740000, 'currencyCode': 'ARS'}}]},
#    'accessInfo': {'country': 'AR',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com.ar/books/download/Research_Methods_for_Reading_Digital_Dat-sample-pdf.acsm?id=aC1WDwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=aC1WDwAAQBAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'This volume explores how digital material might be read or utilized in research, whether that material is digitally born as fanfiction, for example, mostly is, or transposed from other sources.'}},
#   {'kind': 'books#volume',
#    'id': 'l-FRDQAAQBAJ',
#    'etag': 'uo0BSL0Rc64',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/l-FRDQAAQBAJ',
#    'volumeInfo': {'title': 'Doing Digital Humanities',
#     'subtitle': 'Practice, Training, Research',
#     'authors': ['Constance Crompton', 'Richard J Lane', 'Ray Siemens'],
#     'publisher': 'Routledge',
#     'publishedDate': '2016-09-13',
#     'description': 'Digital Humanities is rapidly evolving as a significant approach to/method of teaching, learning and research across the humanities. This is a first-stop book for people interested in getting to grips with digital humanities whether as a student or a professor. The book offers a practical guide to the area as well as offering reflection on the main objectives and processes, including: Accessible introductions of the basics of Digital Humanities through to more complex ideas A wide range of topics from feminist Digital Humanities, digital journal publishing, gaming, text encoding, project management and pedagogy Contextualised case studies Resources for starting Digital Humanities such as links, training materials and exercises Doing Digital Humanities looks at the practicalities of how digital research and creation can enhance both learning and research and offers an approachable way into this complex, yet essential topic.',
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781317481126'},
#      {'type': 'ISBN_10', 'identifier': '1317481127'}],
#     'readingModes': {'text': True, 'image': True},
#     'pageCount': 408,
#     'printType': 'BOOK',
#     'categories': ['Literary Criticism'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '1.2.3.0.preview.3',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=l-FRDQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=l-FRDQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com.ar/books?id=l-FRDQAAQBAJ&printsec=frontcover&dq=digital+humanities&hl=&cd=8&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=l-FRDQAAQBAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=l-FRDQAAQBAJ'},
#    'saleInfo': {'country': 'AR',
#     'saleability': 'FOR_SALE',
#     'isEbook': True,
#     'listPrice': {'amount': 5099, 'currencyCode': 'ARS'},
#     'retailPrice': {'amount': 4059.8, 'currencyCode': 'ARS'},
#     'buyLink': 'https://play.google.com/store/books/details?id=l-FRDQAAQBAJ&rdid=book-l-FRDQAAQBAJ&rdot=1&source=gbs_api',
#     'offers': [{'finskyOfferType': 1,
#       'listPrice': {'amountInMicros': 5099000000, 'currencyCode': 'ARS'},
#       'retailPrice': {'amountInMicros': 4059800000, 'currencyCode': 'ARS'}}]},
#    'accessInfo': {'country': 'AR',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com.ar/books/download/Doing_Digital_Humanities-sample-epub.acsm?id=l-FRDQAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'pdf': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com.ar/books/download/Doing_Digital_Humanities-sample-pdf.acsm?id=l-FRDQAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=l-FRDQAAQBAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'The book offers a practical guide to the area as well as offering reflection on the main objectives and processes, including: Accessible introductions of the basics of Digital Humanities through to more complex ideas A wide range of topics ...'}},
#   {'kind': 'books#volume',
#    'id': 'zQqTAgAAQBAJ',
#    'etag': 'BSD5B/clDQo',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/zQqTAgAAQBAJ',
#    'volumeInfo': {'title': 'The Emergence of the Digital Humanities',
#     'authors': ['Steven E. Jones'],
#     'publisher': 'Routledge',
#     'publishedDate': '2013-08-15',
#     'description': 'The past decade has seen a profound shift in our collective understanding of the digital network. What was once understood to be a transcendent virtual reality is now experienced as a ubiquitous grid of data that we move through and interact with every day, raising new questions about the social, locative, embodied, and object-oriented nature of our experience in the networked world. In The Emergence of the Digital Humanities, Steven E. Jones examines this shift in our relationship to digital technology and the ways that it has affected humanities scholarship and the academy more broadly. Based on the premise that the network is now everywhere rather than merely "out there," Jones links together seemingly disparate cultural events—the essential features of popular social media, the rise of motion-control gaming and mobile platforms, the controversy over the "gamification" of everyday life, the spatial turn, fabrication and 3D printing, and electronic publishing—and argues that cultural responses to changes in technology provide an essential context for understanding the emergence of the digital humanities as a new field of study in this millennium.',
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781136202346'},
#      {'type': 'ISBN_10', 'identifier': '113620234X'}],
#     'readingModes': {'text': True, 'image': True},
#     'pageCount': 224,
#     'printType': 'BOOK',
#     'categories': ['Social Science'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': True,
#     'contentVersion': '1.4.5.0.preview.3',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=zQqTAgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=zQqTAgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com.ar/books?id=zQqTAgAAQBAJ&printsec=frontcover&dq=digital+humanities&hl=&cd=9&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=zQqTAgAAQBAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=zQqTAgAAQBAJ'},
#    'saleInfo': {'country': 'AR',
#     'saleability': 'FOR_SALE',
#     'isEbook': True,
#     'listPrice': {'amount': 0, 'currencyCode': 'ARS'},
#     'retailPrice': {'amount': 0, 'currencyCode': 'ARS'},
#     'buyLink': 'https://play.google.com/store/books/details?id=zQqTAgAAQBAJ&rdid=book-zQqTAgAAQBAJ&rdot=1&source=gbs_api'},
#    'accessInfo': {'country': 'AR',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com.ar/books/download/The_Emergence_of_the_Digital_Humanities-sample-epub.acsm?id=zQqTAgAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'pdf': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com.ar/books/download/The_Emergence_of_the_Digital_Humanities-sample-pdf.acsm?id=zQqTAgAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=zQqTAgAAQBAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'The Open Access version of this book, available at https://doi.org/10.4324/9780203093085, has been made available under a Creative Commons Attribution-Non Commercial-No Derivatives 4.0 license.'}},
#   {'kind': 'books#volume',
#    'id': 'Of9dAQAAQBAJ',
#    'etag': 'hqVoTVX7/WQ',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/Of9dAQAAQBAJ',
#    'volumeInfo': {'title': 'Understanding Digital Humanities',
#     'authors': ['D. Berry'],
#     'publisher': 'Springer',
#     'publishedDate': '2012-02-07',
#     'description': 'Confronting the digital revolution in academia, this book examines the application of new computational techniques and visualisation technologies in the Arts & Humanities. Uniting differing perspectives, leading and emerging scholars discuss the theoretical and practical challenges that computation raises for these disciplines.',
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780230371934'},
#      {'type': 'ISBN_10', 'identifier': '0230371930'}],
#     'readingModes': {'text': True, 'image': True},
#     'pageCount': 318,
#     'printType': 'BOOK',
#     'categories': ['Computers'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': True,
#     'contentVersion': '1.2.2.0.preview.3',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=Of9dAQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=Of9dAQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com.ar/books?id=Of9dAQAAQBAJ&printsec=frontcover&dq=digital+humanities&hl=&cd=10&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=Of9dAQAAQBAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=Of9dAQAAQBAJ'},
#    'saleInfo': {'country': 'AR',
#     'saleability': 'FOR_SALE',
#     'isEbook': True,
#     'listPrice': {'amount': 14731.07, 'currencyCode': 'ARS'},
#     'retailPrice': {'amount': 10311.75, 'currencyCode': 'ARS'},
#     'buyLink': 'https://play.google.com/store/books/details?id=Of9dAQAAQBAJ&rdid=book-Of9dAQAAQBAJ&rdot=1&source=gbs_api',
#     'offers': [{'finskyOfferType': 1,
#       'listPrice': {'amountInMicros': 14731070000, 'currencyCode': 'ARS'},
#       'retailPrice': {'amountInMicros': 10311750000, 'currencyCode': 'ARS'}}]},
#    'accessInfo': {'country': 'AR',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com.ar/books/download/Understanding_Digital_Humanities-sample-epub.acsm?id=Of9dAQAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'pdf': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com.ar/books/download/Understanding_Digital_Humanities-sample-pdf.acsm?id=Of9dAQAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=Of9dAQAAQBAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Confronting the digital revolution in academia, this book examines the application of new computational techniques and visualisation technologies in the Arts &amp; Humanities.'}}]}

# %% [markdown]
# You probably figured out that the books are found under the `items` key, and the most important information for each one is under the `volumeInfo` key. Let's take a look at the first result.

# %%
results['items'][0]['volumeInfo']
# Out:
# {'title': 'Research Methods for the Digital Humanities',
#  'authors': ['lewis levenberg', 'Tai Neilson', 'David Rheams'],
#  'publisher': 'Springer',
#  'publishedDate': '2018-11-04',
#  'description': 'This volume introduces the reader to the wide range of methods that digital humanities employ, and offers a practical guide to the study, interpretation, and presentation of cultural material and practices. In this instance, the editors consider digital humanities to include both the use of computing to understand cultural material in new ways, and the application of theories and methods from the humanities to interpret new technologies. Each chapter provides a step-by-step guide to cutting-edge methodologies so that students can make informed decisions about the methods they use, consider ethical practices, follow practical procedures, and present their work effectively. Readers will develop practical and reflexive understandings of the software and digital devices that they study and use for research, and the book will help new researchers collaborate and contribute to their scholarly communities, and to public discourse. As contemporary humanities work becomes increasingly interdisciplinary, and increasingly permeated by and with digital technologies, this volume helps new researchers navigate an evolving academic environment. Humanities and social sciences students will find this textbook an invaluable resource for assessing and creating digital projects.',
#  'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9783319967134'},
#   {'type': 'ISBN_10', 'identifier': '3319967134'}],
#  'readingModes': {'text': True, 'image': True},
#  'pageCount': 325,
#  'printType': 'BOOK',
#  'categories': ['Social Science'],
#  'maturityRating': 'NOT_MATURE',
#  'allowAnonLogging': False,
#  'contentVersion': '1.2.2.0.preview.3',
#  'panelizationSummary': {'containsEpubBubbles': False,
#   'containsImageBubbles': False},
#  'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=PGV2DwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#   'thumbnail': 'http://books.google.com/books/content?id=PGV2DwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#  'language': 'en',
#  'previewLink': 'http://books.google.com.ar/books?id=PGV2DwAAQBAJ&printsec=frontcover&dq=digital+humanities&hl=&cd=1&source=gbs_api',
#  'infoLink': 'https://play.google.com/store/books/details?id=PGV2DwAAQBAJ&source=gbs_api',
#  'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=PGV2DwAAQBAJ'}

# %% [markdown]
# There's a lot of information in the results, but we probably don't want all of it. Suppose that for each volume in the results, we only want to extract 1) the title, 2) the author(s), 3) the publication date, and 4) the description. Below is a function named `parse_results` that takes the `results` variable as an argument and returns a list of dictionaries. Each dictionary within the list corresponds to a book, and has an `author` key, a `title` key, a `publication_date` key, and a `description` key.

# %%
def parse_results(results):

    results_list = []

    for book in results['items']:

        title = book['volumeInfo']['title']

        # some books don't have authors, dates, or a description
        try:
            authors = ','.join(book['volumeInfo']['authors'])
        except:
            authors = 'NA'
        
        try:
            published_date = book['volumeInfo']['publishedDate']
        except:
            published_date = 'NA'

        try:
            description = book['volumeInfo']['description']
        except:
            description = "NA"

        results_dict = {'title': title,
                        'authors': authors,
                        'description': description,
                        'published_date': published_date}
        
        results_list.append(results_dict)
        
    return(results_list)

# %%
# Use our function to parse the results
data = parse_results(results)
data
# Out:
# [{'title': 'Research Methods for the Digital Humanities',
#   'authors': 'lewis levenberg,Tai Neilson,David Rheams',
#   'description': 'This volume introduces the reader to the wide range of methods that digital humanities employ, and offers a practical guide to the study, interpretation, and presentation of cultural material and practices. In this instance, the editors consider digital humanities to include both the use of computing to understand cultural material in new ways, and the application of theories and methods from the humanities to interpret new technologies. Each chapter provides a step-by-step guide to cutting-edge methodologies so that students can make informed decisions about the methods they use, consider ethical practices, follow practical procedures, and present their work effectively. Readers will develop practical and reflexive understandings of the software and digital devices that they study and use for research, and the book will help new researchers collaborate and contribute to their scholarly communities, and to public discourse. As contemporary humanities work becomes increasingly interdisciplinary, and increasingly permeated by and with digital technologies, this volume helps new researchers navigate an evolving academic environment. Humanities and social sciences students will find this textbook an invaluable resource for assessing and creating digital projects.',
#   'published_date': '2018-11-04'},
#  {'title': 'A New Companion to Digital Humanities',
#   'authors': 'Susan Schreibman,Ray Siemens,John Unsworth',
#   'description': 'This highly-anticipated volume has been extensively revised to reflect changes in technology, digital humanities methods and practices, and institutional culture surrounding the valuation and publication of digital scholarship. A fully revised edition of a celebrated reference work, offering the most comprehensive and up-to-date collection of research currently available in this rapidly evolving discipline Includes new articles addressing topical and provocative issues and ideas such as retro computing, desktop fabrication, gender dynamics, and globalization Brings together a global team of authors who are pioneers of innovative research in the digital humanities Accessibly structured into five sections exploring infrastructures, creation, analysis, dissemination, and the future of digital humanities Surveys the past, present, and future of the field, offering essential research for anyone interested in better understanding the theory, methods, and application of the digital humanities',
#   'published_date': '2016-01-26'},
#  {'title': 'Defining Digital Humanities',
#   'authors': 'Dr Edward Vanhoutte',
#   'description': 'This reader brings together the essential readings that have emerged in Digital Humanities. It provides a historical overview of how the term ‘Humanities Computing’ developed into the term ‘Digital Humanities’, and highlights core readings which explore the meaning, scope, and implementation of the field. To contextualize and frame each included reading, the editors and authors provide a commentary on the original piece. There is also an annotated bibliography of other material not included in the text to provide an essential list of reading in the discipline.',
#   'published_date': '2013-12-23'},
#  {'title': 'Digital Humanities in Practice',
#   'authors': 'Claire Warwick,Melissa Terras,Julianne Nyhan',
#   'description': 'This cutting-edge and comprehensive introduction to digital humanities explains the scope of the discipline and state of the art and provides a wide-ranging insight into emerging topics and avenues of research. Each chapter interweaves the expert commentary of leading academics with analysis of current research and practice, exploring the possibilities and challenges that occur when culture and digital technologies intersect. International case studies of projects ranging from crowdsourced manuscript transcription to computational reconstruction of frescoes are included in each chapter, providing a wealth of information and inspiration. QR codes within each chapter link to a dedicated website where additional content, such as further case studies, is located. Key topics covered include: • studying users and readers • social media and crowdsourcing • digitization and digital resources • image processing in the digital humanities • 3D recording and museums • electronic text and text encoding • book history, texts and digital editing • open access and online teaching of digital humanities • institutional models for digital humanities. Readership: This is an essential practical guide for academics, researchers, librarians and professionals involved in the digital humanities. It will also be core reading for all humanities students and those taking courses in the digital humanities in particular.',
#   'published_date': '2012-10-09'},
#  {'title': 'Digital Humanities',
#   'authors': 'David M. Berry,Anders Fagerjord',
#   'description': 'As the twenty-first century unfolds, computers challenge the way in which we think about culture, society and what it is to be human: areas traditionally explored by the humanities. In a world of automation, Big Data, algorithms, Google searches, digital archives, real-time streams and social networks, our use of culture has been changing dramatically. The digital humanities give us powerful theories, methods and tools for exploring new ways of being in a digital age. Berry and Fagerjord provide a compelling guide, exploring the history, intellectual work, key arguments and ideas of this emerging discipline. They also offer an important critique, suggesting ways in which the humanities can be enriched through computing, but also how cultural critique can transform the digital humanities. Digital Humanities will be an essential book for students and researchers in this new field but also related areas, such as media and communications, digital media, sociology, informatics, and the humanities more broadly.',
#   'published_date': '2017-05-30'},
#  {'title': 'The Digital Humanities and the Digital Modern',
#   'authors': 'James Smithies',
#   'description': 'This book provides new critical and methodological approaches to digital humanities, intended to guide technical development as well as critical analysis. Informed by the history of technology and culture and new perspectives on modernity, Smithies grounds his claims in the engineered nature of computing devices and their complex entanglement with our communities, our scholarly traditions, and our sense of self. The distorting mentalité of the digital modern informs our attitudes to computers and computationally intensive research, leading scholars to reject articulations of meaning that admit the interdependence of humans and the complex socio-technological systems we are embedded in. By framing digital humanities with the digital modern, researchers can rebuild our relationship to technical development, and seek perspectives that unite practical and critical activity. This requires close attention to the cyber-infrastructures that inform our research, the software-intensive methods that are producing new knowledge, and the ethical issues implicit in the production of digital humanities tools and methods. The book will be of interest to anyone interested in the intersection of technology with humanities research, and the future of digital humanities.',
#   'published_date': '2017-08-28'},
#  {'title': 'Research Methods for Reading Digital Data in the Digital Humanities',
#   'authors': 'Gabriele Griffin',
#   'description': 'The first volume to introduce the techniques and methods of reading digital material for researchDigital Humanities has become one of the new domains of academe at the interface of technological development, epistemological change, and methodological concerns. This volume explores how digital material might be read or utilized in research, whether that material is digitally born as fanfiction, for example, mostly is, or transposed from other sources. The volume asks questions such as what happens when text is transformed from printed into digital matter, and how that impacts on the methods we bring to bear on exploring that technologized matter, for example in the case of digital editions. Issues such as how to analyse visual material in digital archives or Twitter feeds, how to engage in data mining, what it means to undertake crowd-sourcing, big data, and what digital network analyses can tell us about online interactions are dealt with. This will give Humanities researchers ideas for doing digitally based research and also suggest ways of engaging with new digital research methods. Key featuresFirst volume centred on the navigation and interpretation of digital material as research methods in the HumanitiesUp-to-date analyses of issues and methods including big data, crowdsourcing, digital network analysis, working with digital additionsBased on actual research projects such as para-textual work with fanfiction, reading twitter, different kinds of distant and close readings',
#   'published_date': '2016-02-15'},
#  {'title': 'Doing Digital Humanities',
#   'authors': 'Constance Crompton,Richard J Lane,Ray Siemens',
#   'description': 'Digital Humanities is rapidly evolving as a significant approach to/method of teaching, learning and research across the humanities. This is a first-stop book for people interested in getting to grips with digital humanities whether as a student or a professor. The book offers a practical guide to the area as well as offering reflection on the main objectives and processes, including: Accessible introductions of the basics of Digital Humanities through to more complex ideas A wide range of topics from feminist Digital Humanities, digital journal publishing, gaming, text encoding, project management and pedagogy Contextualised case studies Resources for starting Digital Humanities such as links, training materials and exercises Doing Digital Humanities looks at the practicalities of how digital research and creation can enhance both learning and research and offers an approachable way into this complex, yet essential topic.',
#   'published_date': '2016-09-13'},
#  {'title': 'The Emergence of the Digital Humanities',
#   'authors': 'Steven E. Jones',
#   'description': 'The past decade has seen a profound shift in our collective understanding of the digital network. What was once understood to be a transcendent virtual reality is now experienced as a ubiquitous grid of data that we move through and interact with every day, raising new questions about the social, locative, embodied, and object-oriented nature of our experience in the networked world. In The Emergence of the Digital Humanities, Steven E. Jones examines this shift in our relationship to digital technology and the ways that it has affected humanities scholarship and the academy more broadly. Based on the premise that the network is now everywhere rather than merely "out there," Jones links together seemingly disparate cultural events—the essential features of popular social media, the rise of motion-control gaming and mobile platforms, the controversy over the "gamification" of everyday life, the spatial turn, fabrication and 3D printing, and electronic publishing—and argues that cultural responses to changes in technology provide an essential context for understanding the emergence of the digital humanities as a new field of study in this millennium.',
#   'published_date': '2013-08-15'},
#  {'title': 'Understanding Digital Humanities',
#   'authors': 'D. Berry',
#   'description': 'Confronting the digital revolution in academia, this book examines the application of new computational techniques and visualisation technologies in the Arts & Humanities. Uniting differing perspectives, leading and emerging scholars discuss the theoretical and practical challenges that computation raises for these disciplines.',
#   'published_date': '2012-02-07'}]

# %%
# Convert the results into a dataframe
results_df = pd.DataFrame(data)
results_df
# Out:
#                                                title  \
# 0        Research Methods for the Digital Humanities
# 1              A New Companion to Digital Humanities
# 2                        Defining Digital Humanities
# 3                     Digital Humanities in Practice
# 4                                 Digital Humanities
# 5      The Digital Humanities and the Digital Modern
# 6  Research Methods for Reading Digital Data in t...
# 7                           Doing Digital Humanities
# 8            The Emergence of the Digital Humanities
# 9                   Understanding Digital Humanities
#
#                                          authors  \
# 0       lewis levenberg,Tai Neilson,David Rheams
# 1     Susan Schreibman,Ray Siemens,John Unsworth
# 2                            Dr Edward Vanhoutte
# 3   Claire Warwick,Melissa Terras,Julianne Nyhan
# 4                David M. Berry,Anders Fagerjord
# 5                                 James Smithies
# 6                               Gabriele Griffin
# 7  Constance Crompton,Richard J Lane,Ray Siemens
# 8                                Steven E. Jones
# 9                                       D. Berry
#
#                                          description published_date
# 0  This volume introduces the reader to the wide ...     2018-11-04
# 1  This highly-anticipated volume has been extens...     2016-01-26
# 2  This reader brings together the essential read...     2013-12-23
# 3  This cutting-edge and comprehensive introducti...     2012-10-09
# 4  As the twenty-first century unfolds, computers...     2017-05-30
# 5  This book provides new critical and methodolog...     2017-08-28
# 6  The first volume to introduce the techniques a...     2016-02-15
# 7  Digital Humanities is rapidly evolving as a si...     2016-09-13
# 8  The past decade has seen a profound shift in o...     2013-08-15
# 9  Confronting the digital revolution in academia...     2012-02-07

# %% [markdown]
# Now let's explore the API using more parameters. You may have noticed that our query only gave us 10 books, but there are probably more than 10 books written about digital humanities. To adjust our search, we need to add in the `maxResults` parameter and the `startIndex` parameter. We can do that by adding these as keys to the `parameters` dictionary, and then run our request again. To read about these parameters, see the [documentation](https://developers.google.com/books/docs/v1/using#api_params).

# %%
# %pwd
# Out:
# '/Users/tomvannuenen/Documents/GitHub/DIGHUM101-2022/Notebooks/Week3'

# %%
parameters = {'q': query,
              'startIndex': 0,
              'maxResults': 10} # max 40 per request, as per documentation

r = requests.get(books_url, params = parameters)

print(r.url)

results = r.json()

print()

parse_results(results)
# Out:
# https://www.googleapis.com/books/v1/volumes?q=digital+humanities&startIndex=0&maxResults=10
# [{'title': 'Research Methods for the Digital Humanities',
#   'authors': 'lewis levenberg,Tai Neilson,David Rheams',
#   'description': 'This volume introduces the reader to the wide range of methods that digital humanities employ, and offers a practical guide to the study, interpretation, and presentation of cultural material and practices. In this instance, the editors consider digital humanities to include both the use of computing to understand cultural material in new ways, and the application of theories and methods from the humanities to interpret new technologies. Each chapter provides a step-by-step guide to cutting-edge methodologies so that students can make informed decisions about the methods they use, consider ethical practices, follow practical procedures, and present their work effectively. Readers will develop practical and reflexive understandings of the software and digital devices that they study and use for research, and the book will help new researchers collaborate and contribute to their scholarly communities, and to public discourse. As contemporary humanities work becomes increasingly interdisciplinary, and increasingly permeated by and with digital technologies, this volume helps new researchers navigate an evolving academic environment. Humanities and social sciences students will find this textbook an invaluable resource for assessing and creating digital projects.',
#   'published_date': '2018-11-04'},
#  {'title': 'A New Companion to Digital Humanities',
#   'authors': 'Susan Schreibman,Ray Siemens,John Unsworth',
#   'description': 'This highly-anticipated volume has been extensively revised to reflect changes in technology, digital humanities methods and practices, and institutional culture surrounding the valuation and publication of digital scholarship. A fully revised edition of a celebrated reference work, offering the most comprehensive and up-to-date collection of research currently available in this rapidly evolving discipline Includes new articles addressing topical and provocative issues and ideas such as retro computing, desktop fabrication, gender dynamics, and globalization Brings together a global team of authors who are pioneers of innovative research in the digital humanities Accessibly structured into five sections exploring infrastructures, creation, analysis, dissemination, and the future of digital humanities Surveys the past, present, and future of the field, offering essential research for anyone interested in better understanding the theory, methods, and application of the digital humanities',
#   'published_date': '2016-01-26'},
#  {'title': 'Defining Digital Humanities',
#   'authors': 'Dr Edward Vanhoutte',
#   'description': 'This reader brings together the essential readings that have emerged in Digital Humanities. It provides a historical overview of how the term ‘Humanities Computing’ developed into the term ‘Digital Humanities’, and highlights core readings which explore the meaning, scope, and implementation of the field. To contextualize and frame each included reading, the editors and authors provide a commentary on the original piece. There is also an annotated bibliography of other material not included in the text to provide an essential list of reading in the discipline.',
#   'published_date': '2013-12-23'},
#  {'title': 'Digital Humanities in Practice',
#   'authors': 'Claire Warwick,Melissa Terras,Julianne Nyhan',
#   'description': 'This cutting-edge and comprehensive introduction to digital humanities explains the scope of the discipline and state of the art and provides a wide-ranging insight into emerging topics and avenues of research. Each chapter interweaves the expert commentary of leading academics with analysis of current research and practice, exploring the possibilities and challenges that occur when culture and digital technologies intersect. International case studies of projects ranging from crowdsourced manuscript transcription to computational reconstruction of frescoes are included in each chapter, providing a wealth of information and inspiration. QR codes within each chapter link to a dedicated website where additional content, such as further case studies, is located. Key topics covered include: • studying users and readers • social media and crowdsourcing • digitization and digital resources • image processing in the digital humanities • 3D recording and museums • electronic text and text encoding • book history, texts and digital editing • open access and online teaching of digital humanities • institutional models for digital humanities. Readership: This is an essential practical guide for academics, researchers, librarians and professionals involved in the digital humanities. It will also be core reading for all humanities students and those taking courses in the digital humanities in particular.',
#   'published_date': '2012-10-09'},
#  {'title': 'Digital Humanities',
#   'authors': 'David M. Berry,Anders Fagerjord',
#   'description': 'As the twenty-first century unfolds, computers challenge the way in which we think about culture, society and what it is to be human: areas traditionally explored by the humanities. In a world of automation, Big Data, algorithms, Google searches, digital archives, real-time streams and social networks, our use of culture has been changing dramatically. The digital humanities give us powerful theories, methods and tools for exploring new ways of being in a digital age. Berry and Fagerjord provide a compelling guide, exploring the history, intellectual work, key arguments and ideas of this emerging discipline. They also offer an important critique, suggesting ways in which the humanities can be enriched through computing, but also how cultural critique can transform the digital humanities. Digital Humanities will be an essential book for students and researchers in this new field but also related areas, such as media and communications, digital media, sociology, informatics, and the humanities more broadly.',
#   'published_date': '2017-05-30'},
#  {'title': 'The Digital Humanities and the Digital Modern',
#   'authors': 'James Smithies',
#   'description': 'This book provides new critical and methodological approaches to digital humanities, intended to guide technical development as well as critical analysis. Informed by the history of technology and culture and new perspectives on modernity, Smithies grounds his claims in the engineered nature of computing devices and their complex entanglement with our communities, our scholarly traditions, and our sense of self. The distorting mentalité of the digital modern informs our attitudes to computers and computationally intensive research, leading scholars to reject articulations of meaning that admit the interdependence of humans and the complex socio-technological systems we are embedded in. By framing digital humanities with the digital modern, researchers can rebuild our relationship to technical development, and seek perspectives that unite practical and critical activity. This requires close attention to the cyber-infrastructures that inform our research, the software-intensive methods that are producing new knowledge, and the ethical issues implicit in the production of digital humanities tools and methods. The book will be of interest to anyone interested in the intersection of technology with humanities research, and the future of digital humanities.',
#   'published_date': '2017-08-28'},
#  {'title': 'Research Methods for Reading Digital Data in the Digital Humanities',
#   'authors': 'Gabriele Griffin',
#   'description': 'The first volume to introduce the techniques and methods of reading digital material for researchDigital Humanities has become one of the new domains of academe at the interface of technological development, epistemological change, and methodological concerns. This volume explores how digital material might be read or utilized in research, whether that material is digitally born as fanfiction, for example, mostly is, or transposed from other sources. The volume asks questions such as what happens when text is transformed from printed into digital matter, and how that impacts on the methods we bring to bear on exploring that technologized matter, for example in the case of digital editions. Issues such as how to analyse visual material in digital archives or Twitter feeds, how to engage in data mining, what it means to undertake crowd-sourcing, big data, and what digital network analyses can tell us about online interactions are dealt with. This will give Humanities researchers ideas for doing digitally based research and also suggest ways of engaging with new digital research methods. Key featuresFirst volume centred on the navigation and interpretation of digital material as research methods in the HumanitiesUp-to-date analyses of issues and methods including big data, crowdsourcing, digital network analysis, working with digital additionsBased on actual research projects such as para-textual work with fanfiction, reading twitter, different kinds of distant and close readings',
#   'published_date': '2016-02-15'},
#  {'title': 'Doing Digital Humanities',
#   'authors': 'Constance Crompton,Richard J Lane,Ray Siemens',
#   'description': 'Digital Humanities is rapidly evolving as a significant approach to/method of teaching, learning and research across the humanities. This is a first-stop book for people interested in getting to grips with digital humanities whether as a student or a professor. The book offers a practical guide to the area as well as offering reflection on the main objectives and processes, including: Accessible introductions of the basics of Digital Humanities through to more complex ideas A wide range of topics from feminist Digital Humanities, digital journal publishing, gaming, text encoding, project management and pedagogy Contextualised case studies Resources for starting Digital Humanities such as links, training materials and exercises Doing Digital Humanities looks at the practicalities of how digital research and creation can enhance both learning and research and offers an approachable way into this complex, yet essential topic.',
#   'published_date': '2016-09-13'},
#  {'title': 'The Emergence of the Digital Humanities',
#   'authors': 'Steven E. Jones',
#   'description': 'The past decade has seen a profound shift in our collective understanding of the digital network. What was once understood to be a transcendent virtual reality is now experienced as a ubiquitous grid of data that we move through and interact with every day, raising new questions about the social, locative, embodied, and object-oriented nature of our experience in the networked world. In The Emergence of the Digital Humanities, Steven E. Jones examines this shift in our relationship to digital technology and the ways that it has affected humanities scholarship and the academy more broadly. Based on the premise that the network is now everywhere rather than merely "out there," Jones links together seemingly disparate cultural events—the essential features of popular social media, the rise of motion-control gaming and mobile platforms, the controversy over the "gamification" of everyday life, the spatial turn, fabrication and 3D printing, and electronic publishing—and argues that cultural responses to changes in technology provide an essential context for understanding the emergence of the digital humanities as a new field of study in this millennium.',
#   'published_date': '2013-08-15'},
#  {'title': 'Understanding Digital Humanities',
#   'authors': 'D. Berry',
#   'description': 'Confronting the digital revolution in academia, this book examines the application of new computational techniques and visualisation technologies in the Arts & Humanities. Uniting differing perspectives, leading and emerging scholars discuss the theoretical and practical challenges that computation raises for these disciplines.',
#   'published_date': '2012-02-07'}]

# %% [markdown]
# Now, we can write a for-loop to collect the first 100 results into `all_results`. But make sure you use `time.sleep` at the end of each loop! Python is so fast that if you write a for loop without pausing between calls you can overload someone's server, or get yourself (temporarily) banned:

# %%
# See how .sleep works

for x in range(5):
    print(x)
    time.sleep(1) # alter this number to change sleep length
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
parameters = {'q': query,
          'maxResults': 20,
          'startIndex': 0}

all_results = []
for i in range(5):
    print("collecting page " + str(i + 1))
    
    r = requests.get(books_url, params=parameters)
    results = r.json()
    parsed = parse_results(results)
    all_results.extend(parsed)
    
    time.sleep(1) # very important to not overload API!!!
    parameters['startIndex'] += parameters['maxResults'] # note the addition assignment
# Out:
# collecting page 1
# collecting page 2
# collecting page 3
# collecting page 4
# collecting page 5

# %%
print(len(all_results))
# Out:
# 100

# %% [markdown]
# Now we can write this data to a CSV.

# %%
import csv

keys = all_results[0].keys()

with open('books_search.csv', 'w') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(all_results)
